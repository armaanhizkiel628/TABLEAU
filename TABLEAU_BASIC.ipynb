# %% [markdown]
# # Q1 Q1. Explain what Tableau is and why it is preferred over traditional spreadsheet tools for data analysis.Also mention any two industries where Tableau is commonly used and explain one use case
#
# answer
#
# 1. Tableau is a powerful data visualization and business intelligence BI tool developed by Tableau Software. It helps users connect to data sources, analyze data, and create interactive dashboards and visual reports without needing advanced programming skills.
#
# * why preferred
# 2. Advanced Data Visualization
# * Tableau creates interactive charts, dashboards, and graphs.
# *  Excel mostly relies on static charts.
#
# 3. Handling Large Data
# * Tableau can process millions of rows efficiently.
# * Excel slows down or crashes with very large datasets.
#
# 4. Real-Time Data Analysis
# * Tableau can connect to live data sources databases, cloud.
# * Excel usually works with manually updated data.
#
#  INDUSTRY COMMENLY USED
#
# 5. Hospitals used for
#
# * Track patient records
# * Monitor disease trends
# * Optimize hospital resources
#
# *  Example: Visualizing patient admission trends to improve staffing decisions.
#
# 6.  Retail  use Tableau for
#
# * Analyze sales data
# * Track customer behavior
# * Manage inventory
#
#  * Example: Identifying best-selling products and seasonal trends to increase sales.

# %% [markdown]
# # q2
# # After connecting to the Sample – Superstore dataset:
# # a) List the main types of fields available (examples: time-based, geographical, numerical).
# # b) Identify any four Dimensions and any four Measures from the dataset.
# # Hint: Look at the Data Pane on the left side of Tableau and observe blue (Dimensions) and green (Measures) fields
#
# answer
#
# 1. Time-based fields (Date fields)
# * These represent time-related data.
# * Examples: Order Date, Ship Date
# 2. Geographical fields
# * These are used for map-based analysis.
# * Examples: Country, State, City, Region
# 3. Numerical fields (Measures)
# * These contain quantitative values used for calculations.
# * Examples: Sales, Profit, Quantity, Discount
# 4. Categorical fields (Dimensions)
# * These describe categories or groups of data.
# * Examples: Category, Sub-Category, Segment
#
#
# 5. Dimensions (Blue fields):
# * Order ID
# * Customer Name
# * Category
# * Region
#
# 6. Measures (Green fields):
# * Sales
# * Profit
# * Quantity
# * Discount

# %% [markdown]
# ## Q3. Create a Bar Chart showing Total Sales by Category.
# # Explain:
# # Which field goes to Rows
# # Which field goes to Columns
# # Which aggregation is applied to Sales
#
# answer
#
# 1. Sales goes to the Rows shelf
#
# * Because it is a Measure numerical value
# * It represents the total amount of sales
#
# 2. Category goes to the Columns shelf
#
# * Because it is a Dimension categorical field
# * It divides data into groups like Furniture, Technology, etc.
#
#
# 3. he aggregation applied is SUM Sales
#
#
#
# * ![Screenshot 2026-03-23 171927.png](data:image/png;base64,...)

# %% [markdown]
# # Q4. What insight can be gained by comparing Sales and Profit together?
# # Then explain how you would create a chart to analyze Profit by Sub-Category
#
#
# Answer
#
# 1. By comparing Sales and Profit together, we can understand:
#
# * Whether high sales are actually generating profit
# * Identify loss-making products or categories
#   Detect cases where:
# * Sales are high but profit is low due to high costs or discounts
# * Sales are low but profit is high efficient products
#
# 2. KEY INSIGHT
# * Not all high-selling products are profitable. This helps businesses make better decisions on pricing, discounts, and product strategy.
#
#
#
# 3. 1. Drag Dimension
#
# * Drag Sub-Category → Rows shelf
#
# 2. Drag Measure
#
# *  Drag Profit → Columns shelf
#
# 3. Choose chart type
#
# * Select Bar Chart from “Show Me” if needed
#
# 4. Add color for better analysis important
#
# *  Drag Profit → Color
#
# * Positive profit → one color
# * Negative profit → another color
# 5. Sort the chart
#
# *  Click Sort Descending
#
# * Helps quickly identify:
# * Most profitable sub-categories
# * Loss-making sub-categories
#
#
#
# * ![Screenshot 2026-03-23 173748.png](data:image/png;base64,...)

# %% [markdown]
# # Q5.  Create a Line Chart to show Sales Trend over Order Date.
# # Which date level would you choose (Year / Quarter / Month)?
# # Why are line charts suitable for time-based analysis?
#
#
# ANSWER
#
# 1. Month
#
# * Reason
# * Provides a balanced level of detail
# * Shows trends clearly without too much clutter
# * More detailed than Year, but not as crowded as daily data
#
# 2. Line charts are ideal because:
#
# * Show trends over time clearly
#
#  Easy to see increase or decrease in sales
#
# * Display patterns and seasonality
#
#  Identify peak months or slow periods
#
#
# * Continuous data representation
#
#
#  Time is continuous, and line charts connect data points smoothly
# * Easy comparison
#
#
#  Helps compare performance across different time periods
#
#
#
#  * ![Screenshot 2026-03-23 175637.png](data:image/png;base64,...)

# %% [markdown]
# # Q6.  Apply a Basic Filter to display data only for:
# # Region = “West”
# # Category = “Technology”
# # Explain the steps and mention which shelf is used.
#
# ANSWER
#
# 1. The Filters Shelf is used to apply filters in Tableau.
#
# 2. ![Screenshot 2026-03-23 181441.png](data:image/png;base64,...)
#
#
#
#
#
#
#
#
# 3. Apply Region Filter
# * Drag Region → Filters shelf
# * In the dialog box:
# * Select West
# Click OK
# 2. Apply Category Filter
# Drag Category → Filters shelf
# * In the dialog box:
# * Select Technology
# * Click OK

# %% [markdown]
# # Q7. Explain the business importance of geographical analysis.Then describe how you would create a Map showing Sales by State using Sample – Superstore.
#
# ANSWER
#
# 1. Geographical analysis helps businesses understand data based on location.
#
# 2. Benefit
#
# * Identify high-performing regions
#
#  Find where sales are highest
#
# * Detect low-performing areas
#
#  Focus on improvement strategies
#
#
# * Better decision-making
#
#
# Plan marketing, expansion, and logistics
#
#
# * Target customers effectively
#
#
#  Customize products/services by region
#
#
#  3. Drag geographical field
#
# *  Drag State → workspace
#
# * Tableau  recognizes it as a geographical field a  map will be generated
#
# 4. Add Sales data
#
# * Drag Sales → Color Marks card
#
# * States will now be colored based on sales value
#
# *  Drag Sales → Label
#
#
#
# * ![Screenshot 2026-03-23 182942.png](data:image/png;base64,...)

# %% [markdown]
# # Q8. What is the difference between a Worksheet and a Dashboard in Tableau? Why is a dashboard more useful for decision-makers
#
# answer
#
# 1. Worksheet
# * A Worksheet is a single view or chart
# * It is used to = Create one visualization at a time
# * Example= Bar chart, line chart, map
#
# 2. Dashboard
# * A Dashboard is a collection of multiple worksheets
# * It displays= Multiple charts on one screen
# Allows = Interaction between visuals
#
# 3. key difference
#
# * Worksheet
# Single chart/view
#
# * Dashboard
#
# Multiple charts combined
#
# * Worksheet
#
#
# Used for analysis
#
#
# * Dashboard
#
# Used for presentation
#
# * Worksheet
#
# Limited interaction
#
# * Dashboard
#
# Highly interactive
#
#
# * Worksheet
#
# Simple
#
# * Dashboard
#
#
# More comprehensive

# %% [markdown]
# # Q9.  What is Tableau Prep, and why is it important in real-world data projects?
#
#
# # Then explain how you would:
# # Remove null values
# # Remove duplicate records
# # Change incorrect data types (Answer in steps, no tool access required.
#
#
# answer
#
# 1. Tableau Prep is a data preparation tool used to:
#
# * Clean
# * Combine
# * Transform raw data
#
# * before using it in Tableau for analysis.
#
# 2. Ensures clean and accurate data
# * Removes errors before analysis
# 3. Saves time
# *  Automates data cleaning steps
# 4. Handles messy data
# *  Combines multiple data sources
# 5. Improves data quality
# *  Better data = better insights
#
# 6. Remove Null Values
# * Steps
# * Open dataset in Tableau Prep
# * Go to the field containing null values
# * Click on null values shown as Null
# * Select:
#
#  Filter → Exclude
#
#
#  7. Remove Duplicate Records
# * Steps
# * Add a Clean Step
# * Identify duplicate fields (like Order ID, Customer ID)
# * Use
# *  Remove Duplicates option
#
#  Duplicate rows will be removed
#
#
#  8.  Change Incorrect Data Types
# * Steps
# * Select the field (e.g., Date or Sales)
# * Click on the data type icon (Abc, #, calendar)
#
# * Choose correct type:
#
#
# Number
# String
# Date
#
# Data type will be corrected

# %% [markdown]
# # Q10.  A retail manager wants answers to the following:
# # 1 Which category generates the highest profit?
# # 2 Which region performs poorly?
# # 3  How does sales change over time?
# * a) Mention which charts you would use
# * b) Identify one key insight that management could derive
# * c) Explain how this helps in business decision-making
#
# answer
#
# A
#
# 1. Highest profit by category
#
# Bar Chart
#
# Category → Columns
# Profit → Rows
#
# * technology highest profit in category
#
#
# 2. Region performance poor regions
#  Bar Chart or Map
#
# Region → View
# Profit → Color / Rows
#
# * centre region poor performance
#
# 3. Sales change over time
# Line Chart
#
# Order Date → Columns
# Sales → Rows
#
#  * Sales fluctuate over time
# There is an overall increasing trend
# Sales are:
# *  Low at the beginning Jan–Feb
# *  Increase in March
# * Slight drop in mid-year
# *  Peak towards the end  Nov Dec
#
# * Sales are highest towards the end of the year, indicating strong seasonal demand
#
#
#
# * 4 b  Some categories may generate high sales but low profit, and certain regions may consistently perform poorly compared to others.
#
#
# * 5 C
#
#
# * Improve product strategy
#
#  Focus on high-profit categories
#
#
# * Fix underperforming regions
#
#
#  Improve marketing or reduce costs
#
#
# * Plan based on trends
#
#
# Use sales trends to forecast demand
#
#
# * Better resource allocation
#
#
# Invest in profitable areas

# %% [markdown]
# Q10
#
# 1 HIGHEST PROFIT TECHNOLOGY CATEGORY
#
# ![Screenshot 2026-03-23 190753.png](data:image/png;base64,...)

# %% [markdown]
# Q10
#
# 2 REGION POOR PERFORMANCE
#
#
# CENTRE
#
#
#
# ![Screenshot 2026-03-23 191120.png](data:image/png;base64,...)

# %% [markdown]
# Q10
#
# 3 SALE CHANGE OVER TIME
#
#
# ![Screenshot 2026-03-23 190148.png](data:image/png;base64,...)
